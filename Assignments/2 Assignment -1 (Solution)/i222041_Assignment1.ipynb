# %% [markdown]
# # You will use this Notebook for your assignment. Make sure to add comments as they also carry marks.

# %% [markdown]
# #Question 1

# %%
# YOUR CODE HERE
#Tashfeen Abbasi
#i22-2041
#Assignment 1
#DS-D
#Question 1
#`````````````````````````````````````````````````````````````````````````` MENU ``````````````````````````````````````````````````
print("\t\t\t\t\t______________________________________")
print("\t\t\t\t\t|Tashi's Frozen Yogurt and Ice-Creams|")
print("\t\t\t\t\t|____________________________________|")
print("\n")
print("==> Menu <==")
print("\n")
print("----------------------------------------------------------------------------------------------------------------------")
print("\t\t\t\t\t\tFrozen Yogurt")
print("Small")
print("Cone -------- Rs.300")
print("Cup  -------- Rs.250")
print("\n")
print("Medium")
print("Cone -------- Rs.400")
print("Cup  -------- Rs.350")
print("\n")
print("Large")
print("Cone -------- Rs.500")
print("Cup  -------- Rs.450")
print("\n\n")
print("----------------------------------------------------------------------------------------------------------------------")
print("\t\t\t\t\t\tIce Cream")
print("Small")
print("Cone -------- Rs.500")
print("Cup  -------- Rs.450")
print("\n")
print("Medium")
print("Cone -------- Rs.800")
print("Cup  -------- Rs.750")
print("\n")
print("Large")
print("Cone -------- Rs.1000")
print("Cup  -------- Rs.950")
print("\n\n")
print("----------------------------------------------------------------------------------------------------------------------")
print("\t\t\t\t\t\tCookies")
print("Regular(2 pieces)")
print("Raisin     -------- Rs.200")
print("Chocolate  -------- Rs.250")
print("\n")
print("Large(4 pieces)")
print("Raisin     -------- Rs.450")
print("Chocolate  -------- Rs.400")
print("\n\n")
print("----------------------------------------------------------------------------------------------------------------------")
print("\t\t\t\t\t\tTopping")
print("Gummies ------- Rs.200")
print("Nuts    ------- Rs.250")
print("\n\n")
print("----------------------------------------------------------------------------------------------------------------------")
print("\t\t\t\t\t\tSpecial Offer")
print("No phones ------- Rs.200 Discount")
print("\n\n")
print("-------------------------------------------------------------------------------------")
total_order_amount = 0
order_count=0
grand_total=0
dict2={}
while True:
    name = input("Enter your name: ")
    print("\n")
    print("______________________________________________")
    print("|What do you want(Frozen Yogurt / Ice Cream)?|")
    print("|Press F for Frozen Yogurt                   |")
    print("|Press I for Ice Cream                       |")
    print("|Press Q to Quit                             |")
    print("|____________________________________________|")
    a = input().lower()
#````````````````````````````````````````````````````````````````````````` IF ``````````````````````````````````````````````````````
    if a == "q":
        break
        order_total = 0
    order_total = 0
#```````````````````````````````````````````````````````````````````` FROZEN YOUGURT ```````````````````````````````````````````
    if a == "f":
        print("________________________")
        print("|What size do you want?|")
        print("|Press S for Small     |")
        print("|Press M for Medium    |")
        print("|Press L for Large     |")
        print("|______________________|")
        size_fy = input().lower()
        print("_______________________________")
        print("|Which container do you want? |")
        print("|Press C for Cup              |")
        print("|Press V for Cone             |")
        print("|_____________________________|")
        container_fy = input().lower()
        if size_fy in ["s", "m", "l"] and container_fy in ["v"]:
            if size_fy == "s":
                order_total += 300
            elif size_fy == "m":
                order_total += 400
            elif size_fy == "l":
                order_total += 500
        elif size_fy in ["s","m","l"] and container_fy in ["c"]:
            if size_fy == "s":
                order_total += 250
            elif size_fy == "m":
                order_total += 350
            elif size_fy == "l":
                order_total += 450
        else:
            print("Wrong Choice :(")

        print("_________________________________")
        print("|Would you like to add toppings? |")
        print("|Press Y for Yes                 |")
        print("|Press N for No                  |")
        print("|________________________________|")
        top_fy_yn = input().lower()

        if top_fy_yn == "y":
            print("________________________________________")
            print("|Which toppings would you like to add? |")
            print("|Press G for Gummies                   |")
            print("|Press N for Nuts                      |")
            print("|______________________________________|")
            top_fy = input().lower()
            if top_fy == "g":
                order_total += 200
            elif top_fy == "n":
                order_total += 250
            else:
                print("Wrong Choice :(")

        print("__________________________________")
        print("|Would you like to have cookies? |")
        print("|Press Y for Yes                 |")
        print("|Press N for No                  |")
        print("|________________________________|")
        cookies_fy_yn = input().lower()

        if cookies_fy_yn == "y":
            print("_____________________________________")
            print("|Which cookies would you like?      |")
            print("|Press R for Raisins                |")
            print("|Press C for Chocolate              |")
            print("|___________________________________|")
            cookies_fy = input().lower()

            print("____________________________________")
            print("|Which size do you want for cookies?|")
            print("|Press R for Regular               |")
            print("|Press L for Large                 |")
            print("|__________________________________|")
            cookies_fy_size = input().lower()

            if cookies_fy == "r" and cookies_fy_size == "r":
                order_total += 200
            elif cookies_fy == "c" and cookies_fy_size == "r":
                order_total += 250
            elif cookies_fy == "r" and cookies_fy_size == "l":
                order_total += 450
            elif cookies_fy == "c" and cookies_fy_size == "l":
                order_total += 400
            else:
                print("Wrong :(")
        total_order_amount += order_total
        grand_total+=total_order_amount
        print("Total: ", order_total)
        if name in dict2:
            dict2[name] += order_total
        else:
            dict2[name] = order_total
            print("\n")
            print("\t\t\t\t\t______________")
            print("\t\t\t\t\t|   Report   |")
            print("\t\t\t\t\t|____________|")
            print("\n")
        for keys, value in dict2.items():
            print("Customer = {} , Total = {}".format(keys,value))
            print("\n")
            print("-------------------------------------------------------------------------------------")
#```````````````````````````````````````````````````````````````````````` ICE CREAM ````````````````````````````````````````````
    elif a == "i":
#```````````` SIZE(S,M,L) ``````
        print("________________________")
        print("|What size do you want?|")
        print("|Press S for Small     |")
        print("|Press M for Medium    |")
        print("|Press L for Large     |")
        print("|______________________|")
        size_ic = input().lower()
#```````````` CONTAINER(CUP OR CONE) ````````````
        print("_______________________________")
        print("|Which container do you want? |")
        print("|Press C for Cup              |")
        print("|Press V for Cone             |")
        print("|_____________________________|")
        container_ic = input().lower()
        if size_ic in ["s", "m", "l"] and container_ic in ["v"]:
            if size_ic == "s":
                order_total += 500
            elif size_ic == "m":
                order_total += 800
            elif size_ic == "l":
                order_total += 1000
        elif size_ic in ["s","m","l"] and container_ic in ["c"]:
            if size_ic == "s":
                order_total += 450
            elif size_ic == "m":
                order_total += 750
            elif size_ic == "l":
                order_total += 950
        else:
            print("Wrong :(")
#```````````` TOPPINGS(G,N)``````
        print("__________________________________")
        print("|Would you like to add toppings? |")
        print("|Press Y for Yes                 |")
        print("|Press N for No                  |")
        print("|________________________________|")
        top_ic_yn = input().lower()

        if top_ic_yn == "y":
            print("________________________________________")
            print("|Which toppings would you like to add? |")
            print("|Press G for Gummies                   |")
            print("|Press N for Nuts                      |")
            print("|______________________________________|")
            top_ic = input().lower()
            if top_ic == "g":
                order_total += 200
            elif top_ic == "n":
                order_total += 250
        else:
            print("Okay :)")
#```````````` COOKIES(R,C) ````````````
        print("__________________________________")
        print("|Would you like to have cookies? |")
        print("|Press Y for Yes                 |")
        print("|Press N for No                  |")
        print("|________________________________|")
        cookies_ic_yn = input().lower()

        if cookies_ic_yn == "y":
            print("_____________________________________")
            print("|Which cookies would you like?      |")
            print("|Press R for Raisins                |")
            print("|Press C for Chocolate              |")
            print("|___________________________________|")
            cookies_ic = input().lower()
            #```````````` COOKIES SIZE(R,L) ``````
            print("____________________________________")
            print("|Which size do you want for cookies?|")
            print("|Press R for Regular                |")
            print("|Press L for Large                  |")
            print("|___________________________________|")
            cookies_ic_size = input().lower()

            if cookies_ic == "r" and cookies_ic_size == "r":
                order_total += 200
            elif cookies_ic == "c" and cookies_ic_size == "r":
                order_total += 250
            elif cookies_ic == "r" and cookies_ic_size == "l":
                order_total += 450
            elif cookies_ic == "c" and cookies_ic_size == "l":
                order_total += 400
            else:
                print("Wrong :(")
        total_order_amount += order_total
        grand_total+=total_order_amount
        if name in dict2:
            dict2[name] += order_total
        else:
            dict2[name] = order_total
            print("\n")
            print("\t\t\t\t________________________")
            print("\t\t\t\t|  Individual Report   |")
            print("\t\t\t\t|______________________|")
            print("\n")
        for keys, value in dict2.items():
            print("Customer = {} , Total Bill = {}".format(keys,value))
            print("\n")
            print("-------------------------------------------------------------------------------------")
            print("\n\n")
#``````````````````````````````````````````````````````````````````` ELSE ````````````````````````````````````````````````
    else:
        print("Wrong choice!")
        total_order_amount += order_total
        grand_total += total_order_amount
        order_count += 1
        print("Total: ", order_total)
        if name in dict2:
            print("Welcome back")
            dict2[name]["total"] += order_total
            dict2[name]["count"] += 1
        else:
            dict2[name] = {
                "total": order_total,
                "count": 1
                              }
#```````````````````````````````````````````````````````````````````` OVERALL REPORT ``````````````````````````````````````````````
print("\t\t\t\t\t___________________")
print("\t\t\t\t\t|  Overall Report |")
print("\t\t\t\t\t|_________________|")
order_t = []
for keys, values in dict2.items():
    user_total = values
    order_t.append(user_total)
    print("Customer = {},  Order Total = Rs.{}".format(keys, user_total))
    print("\n")
overall_money = sum(order_t)
print("Total Amount for the Day = Rs.{}".format(overall_money))

# %% [markdown]
# #Question 2

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display

# %%
# img = Image.open('PATH')
img = Image.open('test.jpg')
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=549x548>

# %%
img_array = np.array(img)
img_array.shape
# Out:
# (548, 549, 3)

# %%
""" The RGB Values of the first Pixel """
img_array[0][0]
""" You can use the height and width variables in your code to get the rows and columns of pixels in the image """
height = img_array.shape[0]
width = img_array.shape[1]
height,width
# Out:
# (548, 549)

# %%
h, w, _ = img_array.shape
for i in range(h * w):
    x = i // w
    y = i % w
    tashi_img = img_array[x, y]
    if all(channel > 200 for channel in tashi_img):
        img_array[x, y] = [255, 255, 0]
final = Image.fromarray(img_array)
plt.imshow(final)
plt.show()

# %%
white = [255, 255, 255]
yellow = [255, 255, 0]
tashi_img = img_array.reshape(-1, 3)
for i in range(tashi_img.shape[0]):
    if np.mean(tashi_img[i]) < 100:
        tashi_img[i] = yellow
    elif np.mean(tashi_img[i]) > 200:
        tashi_img[i] = white
final = tashi_img.reshape(img_array.shape)
result_img = Image.fromarray(final)
plt.imshow(result_img)
plt.show()

# %% [markdown]
# #Question 3

# %%
import pandas as pd
import numpy as np


df=pd.read_csv("TIMETABLE.csv")

data=pd.DataFrame(df)

df.set_index(df.columns[0], inplace=True)
unique_days = df.iloc[:, 0].unique()
df['Day'] = list(unique_days) * (len(df) // len(unique_days)) + list(unique_days)[:len(df) % len(unique_days)]
unique_days = df.iloc[:, 0].unique()

df['Day'] = list(unique_days) * (len(df) // len(unique_days)) + list(unique_days)[:len(df) % len(unique_days)]
df = df['Day','Time', 'Course', 'Section', 'Type', 'Room']
data
# Out:
#         Day          Time          Course Section    Type   Room
# 0    Monday  03:55-05:15        Info Sec     CS-F  Theory  C-302
# 1    Monday   05:20-06:40  Info Sec ReSch    CS-F  Theory  C-302
# 2    Monday   08:30-09:50             PF     CS-C  Theory  C-303
# 3    Monday   10:00-11:20       Calculus     CS-C  Theory  C-303
# 4    Monday   11:30-01:15        Islamic     CS-C  Theory  C-303
# ..      ...           ...             ...     ...     ...    ...
# 205  Monday   05:10-08:05             NaN     NaN     NaN    NaN
# 206  Monday   08:30-09:50             AP   (CS-B)  Theory  C-302
# 207  Monday   10:00-11:20             PF     CS-B  Theory  C-302
# 208  Monday   11:30-12:50       Calculus     CS-B  Theory  C-302
# 209  Monday    1:30-03:50       Func Eng     CS-B  Theory  C-302
#
# [210 rows x 6 columns]
